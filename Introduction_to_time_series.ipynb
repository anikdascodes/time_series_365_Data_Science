# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/user/miniconda3/lib/python3.12/site-packages (24.3.1)

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in /home/user/miniconda3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/user/miniconda3/lib/python3.12/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/user/miniconda3/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/miniconda3/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/user/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /home/user/miniconda3/lib/python3.12/site-packages (2.1.3)
# Requirement already satisfied: matplotlib in /home/user/miniconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /home/user/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in /home/user/miniconda3/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/user/miniconda3/lib/python3.12/site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in /home/user/miniconda3/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/user/miniconda3/lib/python3.12/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/user/miniconda3/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/miniconda3/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/user/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %% [markdown]
# ### Import the Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### Importing the Data

# %%
raw_csv_data = pd.read_csv("Index2018.csv")

# %%
df_comp = raw_csv_data.copy()

# %% [markdown]
# ### Examing the Data

# %%
df_comp.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df_comp
# Out:
#             date          spx       dax         ftse    nikkei
# 0     07/01/1994   469.900000   2224.95  3445.980000  18124.01
# 1     10/01/1994   475.270000   2225.00  3440.580000  18443.44
# 2     11/01/1994   474.130000   2228.10  3413.770000  18485.25
# 3     12/01/1994   474.170000   2182.06  3372.020000  18793.88
# 4     13/01/1994   472.470000   2142.37  3360.010000  18577.26
# ...          ...          ...       ...          ...       ...
# 6264  23/01/2018  2839.130362  13559.60  7731.827774  24124.15
# 6265  24/01/2018  2837.544008  13414.74  7643.428966  23940.78
# 6266  25/01/2018  2839.253031  13298.36  7615.839954  23669.49
# 6267  26/01/2018  2872.867839  13340.17  7665.541292  23631.88
# 6268  29/01/2018  2853.528411  13324.48  7671.533300  23629.34
#
# [6269 rows x 5 columns]

# %%
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
df_comp.isna()
# Out:
#        date    spx    dax   ftse  nikkei
# 0     False  False  False  False   False
# 1     False  False  False  False   False
# 2     False  False  False  False   False
# 3     False  False  False  False   False
# 4     False  False  False  False   False
# ...     ...    ...    ...    ...     ...
# 6264  False  False  False  False   False
# 6265  False  False  False  False   False
# 6266  False  False  False  False   False
# 6267  False  False  False  False   False
# 6268  False  False  False  False   False
#
# [6269 rows x 5 columns]

# %%
df_comp.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
df_comp.spx.isna().sum()
# Out:
# np.int64(0)
